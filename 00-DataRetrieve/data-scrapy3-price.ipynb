# %% [markdown]
# get the data from https://www.dekudeals.com/
#
# this website can know the price of each game

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import time
import os

# %%
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd
import random
import concurrent.futures
import threading

# 基本設定
base_url = "https://www.dekudeals.com/games"

# 更完整的headers模擬真實瀏覽器
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8",
    "Accept-Language": "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7",
    "Accept-Encoding": "gzip, deflate, br",
    "Connection": "keep-alive",
    "Referer": "https://www.dekudeals.com/",
    "Cache-Control": "max-age=0"
}

# 用於存儲所有遊戲數據和鎖
all_games = []
lock = threading.Lock()

# 函數：爬取一頁內容
def scrape_page(page_num):
    url = f"{base_url}?page={page_num}"
    
    try:
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, "html.parser")
            
            # 檢查是否有遊戲卡片
            game_cards = soup.select("div.col.pb-4.d-block")
            
            page_games = []
            for card in game_cards:
                # 遊戲名稱
                name_tag = card.select_one("h6.line-clamp-2.mt-1")
                game_name = name_tag.text.strip() if name_tag else "N/A"
                
                # 原價
                original_price_tag = card.select_one("s.text-muted")
                original_price = original_price_tag.text.strip() if original_price_tag else "N/A"
                
                # 現價
                current_price_tag = card.select_one("strong")
                current_price = current_price_tag.text.strip() if current_price_tag else "N/A"
                
                # 折扣百分比
                discount_tag = card.select_one("span.badge.badge-danger")
                discount = discount_tag.text.strip() if discount_tag else "N/A"
                
                # 價格標籤
                price_label_tag = card.select_one("span.badge.badge-warning")
                price_label = price_label_tag.text.strip() if price_label_tag else "N/A"
                
                # 銷售結束日期
                sale_ends_tag = card.select_one("div.w-100")
                sale_ends = sale_ends_tag.text.strip() if sale_ends_tag else "N/A"
                
                # 遊戲鏈接
                link_tag = card.select_one("a.main-link")
                game_link = link_tag['href'] if link_tag and 'href' in link_tag.attrs else "N/A"
                
                game_data = {
                    "遊戲名稱": game_name,
                    "原價": original_price,
                    "現價": current_price,
                    "折扣": discount,
                    "價格標籤": price_label,
                    "銷售結束": sale_ends,
                    "遊戲鏈接": game_link,
                    "頁碼": page_num
                }
                
                page_games.append(game_data)
                
            return page_games
        else:
            print(f"  請求失敗，狀態碼: {response.status_code}")
            return []
    except Exception as e:
        print(f"  爬取出錯: {e}")
        return []

# 函數：嘗試找出總頁數
def find_total_pages():
    response = requests.get(base_url, headers=headers)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, "html.parser")
        
        # 查找分頁信息
        pagination = soup.select("ul.pagination li a.page-link")
        if pagination:
            # 尋找所有頁碼
            page_numbers = []
            for link in pagination:
                try:
                    if link.text.strip().isdigit():
                        page_numbers.append(int(link.text.strip()))
                except:
                    pass
                    
            if page_numbers:
                return max(page_numbers)
    else:
        return response.status_code
    
# 主爬蟲函數
def main():
    # 嘗試找出總頁數
    estimated_total_pages = find_total_pages()
    print(f"預估總頁數: {estimated_total_pages}")
    
    max_worker_thread = 2
    print(f'使用 {max_worker_thread} 個執行緒')

    # 使用執行緒池進行並行爬取
    with concurrent.futures.ThreadPoolExecutor(max_workers=max_worker_thread) as executor:
        # 提交所有頁面的爬取任務
        future_to_page = {executor.submit(scrape_page, page): page for page in range(1, estimated_total_pages + 1)}
        
        # 獲取結果
        completed_pages = 0
        for future in concurrent.futures.as_completed(future_to_page):
            page = future_to_page[future]
            try:
                # 獲取並保存爬取結果 - 這是修復的關鍵
                page_data = future.result()
                if page_data:
                    # 使用鎖保護共享資源
                    with lock:
                        all_games.extend(page_data)
                
                completed_pages += 1
                print(f"第 {page} 頁爬取完成 (進度: {completed_pages}/{estimated_total_pages})")
                
                # 適度延遲避免請求過快
                time.sleep(random.uniform(0.5, 1))
            
            except Exception as e:
                print(f"處理第 {page} 頁結果時出錯: {e}")
    
    # 將結果轉換為DataFrame
    if all_games:
        df = pd.DataFrame(all_games)
        
        # 顯示結果統計
        print("\n爬取完成！")
        print(f"總共爬取了 {len(all_games)} 個遊戲數據，共 {estimated_total_pages} 頁")
        print("\n數據預覽:")
        print(df.head())
        
        # 保存到CSV文件
        csv_filename = "dekudeals_games.csv"
        df.to_csv(csv_filename, index=False, encoding='utf-8-sig')
        print(f"\n數據已保存到 {csv_filename}")
    else:
        print("沒有爬取到任何遊戲數據")

# 執行主函數
if __name__ == "__main__":
    main()
# Out:
# 預估總頁數: 566
# 使用 2 個執行緒
# 第 1 頁爬取完成 (進度: 1/566)
# 第 2 頁爬取完成 (進度: 2/566)
# 第 3 頁爬取完成 (進度: 3/566)
# 第 4 頁爬取完成 (進度: 4/566)
# 第 6 頁爬取完成 (進度: 5/566)
# 第 5 頁爬取完成 (進度: 6/566)
# 第 7 頁爬取完成 (進度: 7/566)
# 第 8 頁爬取完成 (進度: 8/566)
# 第 9 頁爬取完成 (進度: 9/566)
# 第 10 頁爬取完成 (進度: 10/566)
# 第 11 頁爬取完成 (進度: 11/566)
# 第 12 頁爬取完成 (進度: 12/566)
# 第 13 頁爬取完成 (進度: 13/566)
# 第 14 頁爬取完成 (進度: 14/566)
# 第 15 頁爬取完成 (進度: 15/566)
# 第 16 頁爬取完成 (進度: 16/566)
# 第 18 頁爬取完成 (進度: 17/566)
# 第 17 頁爬取完成 (進度: 18/566)
# 第 20 頁爬取完成 (進度: 19/566)
# 第 19 頁爬取完成 (進度: 20/566)
# 第 22 頁爬取完成 (進度: 21/566)
# 第 21 頁爬取完成 (進度: 22/566)
# 第 24 頁爬取完成 (進度: 23/566)
# 第 23 頁爬取完成 (進度: 24/566)
# 第 25 頁爬取完成 (進度: 25/566)
# 第 26 頁爬取完成 (進度: 26/566)
# 第 27 頁爬取完成 (進度: 27/566)
# 第 28 頁爬取完成 (進度: 28/566)
# 第 29 頁爬取完成 (進度: 29/566)
# 第 30 頁爬取完成 (進度: 30/566)
# 第 31 頁爬取完成 (進度: 31/566)
# 第 32 頁爬取完成 (進度: 32/566)
# 第 33 頁爬取完成 (進度: 33/566)
# 第 34 頁爬取完成 (進度: 34/566)
# 第 35 頁爬取完成 (進度: 35/566)
# 第 36 頁爬取完成 (進度: 36/566)
# 第 37 頁爬取完成 (進度: 37/566)
# 第 38 頁爬取完成 (進度: 38/566)
# 第 39 頁爬取完成 (進度: 39/566)
# 第 40 頁爬取完成 (進度: 40/566)
# 第 41 頁爬取完成 (進度: 41/566)
# 第 42 頁爬取完成 (進度: 42/566)
# 第 43 頁爬取完成 (進度: 43/566)
# 第 44 頁爬取完成 (進度: 44/566)
# 第 45 頁爬取完成 (進度: 45/566)
# 第 46 頁爬取完成 (進度: 46/566)
# 第 47 頁爬取完成 (進度: 47/566)
# 第 48 頁爬取完成 (進度: 48/566)
# 第 49 頁爬取完成 (進度: 49/566)
# 第 50 頁爬取完成 (進度: 50/566)
# 第 51 頁爬取完成 (進度: 51/566)
# 第 53 頁爬取完成 (進度: 52/566)
# 第 253 頁爬取完成 (進度: 252/566)
# 第 252 頁爬取完成 (進度: 253/566)
# 第 254 頁爬取完成 (進度: 254/566)
# 第 255 頁爬取完成 (進度: 255/566)
# 第 256 頁爬取完成 (進度: 256/566)
# 第 257 頁爬取完成 (進度: 257/566)
# 第 258 頁爬取完成 (進度: 258/566)
# 第 259 頁爬取完成 (進度: 259/566)
# 第 260 頁爬取完成 (進度: 260/566)
# 第 261 頁爬取完成 (進度: 261/566)
# 第 262 頁爬取完成 (進度: 262/566)
# 第 263 頁爬取完成 (進度: 263/566)
# 第 264 頁爬取完成 (進度: 264/566)
# 第 265 頁爬取完成 (進度: 265/566)
# 第 266 頁爬取完成 (進度: 266/566)
# 第 267 頁爬取完成 (進度: 267/566)
# 第 268 頁爬取完成 (進度: 268/566)
# 第 269 頁爬取完成 (進度: 269/566)
# 第 270 頁爬取完成 (進度: 270/566)
# 第 271 頁爬取完成 (進度: 271/566)
# 第 272 頁爬取完成 (進度: 272/566)
# 第 273 頁爬取完成 (進度: 273/566)
# 第 274 頁爬取完成 (進度: 274/566)
# 第 275 頁爬取完成 (進度: 275/566)
# 第 276 頁爬取完成 (進度: 276/566)
# 第 277 頁爬取完成 (進度: 277/566)
# 第 278 頁爬取完成 (進度: 278/566)
# 第 279 頁爬取完成 (進度: 279/566)
# 第 280 頁爬取完成 (進度: 280/566)
# 第 281 頁爬取完成 (進度: 281/566)
# 第 282 頁爬取完成 (進度: 282/566)
# 第 283 頁爬取完成 (進度: 283/566)
# 第 284 頁爬取完成 (進度: 284/566)
# 第 285 頁爬取完成 (進度: 285/566)
# 第 286 頁爬取完成 (進度: 286/566)
# 第 287 頁爬取完成 (進度: 287/566)
# 第 288 頁爬取完成 (進度: 288/566)
# 第 289 頁爬取完成 (進度: 289/566)
# 第 290 頁爬取完成 (進度: 290/566)
# 第 291 頁爬取完成 (進度: 291/566)
# 第 292 頁爬取完成 (進度: 292/566)
# 第 293 頁爬取完成 (進度: 293/566)
# 第 294 頁爬取完成 (進度: 294/566)
# 第 295 頁爬取完成 (進度: 295/566)
# 第 296 頁爬取完成 (進度: 296/566)
# 第 297 頁爬取完成 (進度: 297/566)
# 第 298 頁爬取完成 (進度: 298/566)
# 第 299 頁爬取完成 (進度: 299/566)
# 第 300 頁爬取完成 (進度: 300/566)
# 第 301 頁爬取完成 (進度: 301/566)
# 第 302 頁爬取完成 (進度: 302/566)
# 第 303 頁爬取完成 (進度: 303/566)
# 第 304 頁爬取完成 (進度: 304/566)
# 第 305 頁爬取完成 (進度: 305/566)
# 第 306 頁爬取完成 (進度: 306/566)
# 第 307 頁爬取完成 (進度: 307/566)
# 第 308 頁爬取完成 (進度: 308/566)
# 第 309 頁爬取完成 (進度: 309/566)
# 第 310 頁爬取完成 (進度: 310/566)
# 第 311 頁爬取完成 (進度: 311/566)
# 第 312 頁爬取完成 (進度: 312/566)
# 第 313 頁爬取完成 (進度: 313/566)
# 第 314 頁爬取完成 (進度: 314/566)
# 第 315 頁爬取完成 (進度: 315/566)
# 第 316 頁爬取完成 (進度: 316/566)
# 第 317 頁爬取完成 (進度: 317/566)
# 第 384 頁爬取完成 (進度: 384/566)
# 第 385 頁爬取完成 (進度: 385/566)
# 第 386 頁爬取完成 (進度: 386/566)
# 第 387 頁爬取完成 (進度: 387/566)
# 第 388 頁爬取完成 (進度: 388/566)
# 第 389 頁爬取完成 (進度: 389/566)
# 第 390 頁爬取完成 (進度: 390/566)
# 第 391 頁爬取完成 (進度: 391/566)
# 第 392 頁爬取完成 (進度: 392/566)
# 第 393 頁爬取完成 (進度: 393/566)
# 第 394 頁爬取完成 (進度: 394/566)
# 第 395 頁爬取完成 (進度: 395/566)
# 第 396 頁爬取完成 (進度: 396/566)
# 第 398 頁爬取完成 (進度: 397/566)
# 第 397 頁爬取完成 (進度: 398/566)
# 第 399 頁爬取完成 (進度: 399/566)
# 第 400 頁爬取完成 (進度: 400/566)
# 第 401 頁爬取完成 (進度: 401/566)
# 第 402 頁爬取完成 (進度: 402/566)
# 第 403 頁爬取完成 (進度: 403/566)
# 第 404 頁爬取完成 (進度: 404/566)
# 第 405 頁爬取完成 (進度: 405/566)
# 第 406 頁爬取完成 (進度: 406/566)
# 第 407 頁爬取完成 (進度: 407/566)
# 第 408 頁爬取完成 (進度: 408/566)
# 第 409 頁爬取完成 (進度: 409/566)
# 第 410 頁爬取完成 (進度: 410/566)
# 第 412 頁爬取完成 (進度: 411/566)
# 第 411 頁爬取完成 (進度: 412/566)
# 第 414 頁爬取完成 (進度: 413/566)
# 第 413 頁爬取完成 (進度: 414/566)
# 第 415 頁爬取完成 (進度: 415/566)
# 第 416 頁爬取完成 (進度: 416/566)
# 第 417 頁爬取完成 (進度: 417/566)
# 第 418 頁爬取完成 (進度: 418/566)
# 第 419 頁爬取完成 (進度: 419/566)
# 第 420 頁爬取完成 (進度: 420/566)
# 第 421 頁爬取完成 (進度: 421/566)
# 第 422 頁爬取完成 (進度: 422/566)
# 第 424 頁爬取完成 (進度: 423/566)
# 第 423 頁爬取完成 (進度: 424/566)
# 第 426 頁爬取完成 (進度: 425/566)
# 第 425 頁爬取完成 (進度: 426/566)
# 第 428 頁爬取完成 (進度: 427/566)
# 第 427 頁爬取完成 (進度: 428/566)
# 第 429 頁爬取完成 (進度: 429/566)
# 第 430 頁爬取完成 (進度: 430/566)
# 第 431 頁爬取完成 (進度: 431/566)
# 第 432 頁爬取完成 (進度: 432/566)
# 第 433 頁爬取完成 (進度: 433/566)
# 第 434 頁爬取完成 (進度: 434/566)
# 第 436 頁爬取完成 (進度: 435/566)
# 第 435 頁爬取完成 (進度: 436/566)
# 第 437 頁爬取完成 (進度: 437/566)
# 第 438 頁爬取完成 (進度: 438/566)
# 第 439 頁爬取完成 (進度: 439/566)
# 第 440 頁爬取完成 (進度: 440/566)
# 第 442 頁爬取完成 (進度: 441/566)
# 第 441 頁爬取完成 (進度: 442/566)
# 第 443 頁爬取完成 (進度: 443/566)
# 第 444 頁爬取完成 (進度: 444/566)
# 第 446 頁爬取完成 (進度: 445/566)
# 第 445 頁爬取完成 (進度: 446/566)
# 第 447 頁爬取完成 (進度: 447/566)
# 第 448 頁爬取完成 (進度: 448/566)
# 第 449 頁爬取完成 (進度: 449/566)
# 第 450 頁爬取完成 (進度: 450/566)
# 第 452 頁爬取完成 (進度: 451/566)
# 第 451 頁爬取完成 (進度: 452/566)
# 第 453 頁爬取完成 (進度: 453/566)
# 第 454 頁爬取完成 (進度: 454/566)
# 第 455 頁爬取完成 (進度: 455/566)
# 第 456 頁爬取完成 (進度: 456/566)
# 第 457 頁爬取完成 (進度: 457/566)
# 第 458 頁爬取完成 (進度: 458/566)
# 第 459 頁爬取完成 (進度: 459/566)
# 第 460 頁爬取完成 (進度: 460/566)
# 第 461 頁爬取完成 (進度: 461/566)
# 第 462 頁爬取完成 (進度: 462/566)
# 第 464 頁爬取完成 (進度: 463/566)
# 第 463 頁爬取完成 (進度: 464/566)
# 第 465 頁爬取完成 (進度: 465/566)
# 第 466 頁爬取完成 (進度: 466/566)
# 第 467 頁爬取完成 (進度: 467/566)
# 第 468 頁爬取完成 (進度: 468/566)
# 第 469 頁爬取完成 (進度: 469/566)
# 第 470 頁爬取完成 (進度: 470/566)
# 第 471 頁爬取完成 (進度: 471/566)
# 第 472 頁爬取完成 (進度: 472/566)
# 第 473 頁爬取完成 (進度: 473/566)
# 第 474 頁爬取完成 (進度: 474/566)
# 第 475 頁爬取完成 (進度: 475/566)
# 第 476 頁爬取完成 (進度: 476/566)
# 第 477 頁爬取完成 (進度: 477/566)
# 第 478 頁爬取完成 (進度: 478/566)
# 第 480 頁爬取完成 (進度: 479/566)
# 第 479 頁爬取完成 (進度: 480/566)
# 第 482 頁爬取完成 (進度: 481/566)
# 第 481 頁爬取完成 (進度: 482/566)
# 第 484 頁爬取完成 (進度: 483/566)
# 第 483 頁爬取完成 (進度: 484/566)
# 第 485 頁爬取完成 (進度: 485/566)
# 第 486 頁爬取完成 (進度: 486/566)
# 第 488 頁爬取完成 (進度: 487/566)
# 第 487 頁爬取完成 (進度: 488/566)
# 第 489 頁爬取完成 (進度: 489/566)
# 第 490 頁爬取完成 (進度: 490/566)
# 第 491 頁爬取完成 (進度: 491/566)
# 第 492 頁爬取完成 (進度: 492/566)
# 第 494 頁爬取完成 (進度: 493/566)
# 第 493 頁爬取完成 (進度: 494/566)
# 第 496 頁爬取完成 (進度: 495/566)
# 第 495 頁爬取完成 (進度: 496/566)
# 第 497 頁爬取完成 (進度: 497/566)
# 第 498 頁爬取完成 (進度: 498/566)
# 第 500 頁爬取完成 (進度: 499/566)
# 第 499 頁爬取完成 (進度: 500/566)
# 第 501 頁爬取完成 (進度: 501/566)
# 第 502 頁爬取完成 (進度: 502/566)
# 第 504 頁爬取完成 (進度: 503/566)
# 第 503 頁爬取完成 (進度: 504/566)
# 第 505 頁爬取完成 (進度: 505/566)
# 第 506 頁爬取完成 (進度: 506/566)
# 第 508 頁爬取完成 (進度: 507/566)
# 第 507 頁爬取完成 (進度: 508/566)
# 第 510 頁爬取完成 (進度: 509/566)
# 第 509 頁爬取完成 (進度: 510/566)
# 第 511 頁爬取完成 (進度: 511/566)
# 第 512 頁爬取完成 (進度: 512/566)
# 第 513 頁爬取完成 (進度: 513/566)
# 第 514 頁爬取完成 (進度: 514/566)
# 第 515 頁爬取完成 (進度: 515/566)
# 第 516 頁爬取完成 (進度: 516/566)
# 第 517 頁爬取完成 (進度: 517/566)
# 第 518 頁爬取完成 (進度: 518/566)
# 第 519 頁爬取完成 (進度: 519/566)
# 第 520 頁爬取完成 (進度: 520/566)
# 第 522 頁爬取完成 (進度: 521/566)
# 第 521 頁爬取完成 (進度: 522/566)
# 第 523 頁爬取完成 (進度: 523/566)
# 第 524 頁爬取完成 (進度: 524/566)
# 第 525 頁爬取完成 (進度: 525/566)
# 第 526 頁爬取完成 (進度: 526/566)
# 第 528 頁爬取完成 (進度: 527/566)
# 第 527 頁爬取完成 (進度: 528/566)
# 第 530 頁爬取完成 (進度: 529/566)
# 第 529 頁爬取完成 (進度: 530/566)
# 第 532 頁爬取完成 (進度: 531/566)
# 第 531 頁爬取完成 (進度: 532/566)
# 第 533 頁爬取完成 (進度: 533/566)
# 第 534 頁爬取完成 (進度: 534/566)
# 第 535 頁爬取完成 (進度: 535/566)
# 第 536 頁爬取完成 (進度: 536/566)
# 第 537 頁爬取完成 (進度: 537/566)
# 第 538 頁爬取完成 (進度: 538/566)
# 第 539 頁爬取完成 (進度: 539/566)
# 第 540 頁爬取完成 (進度: 540/566)
# 第 541 頁爬取完成 (進度: 541/566)
# 第 542 頁爬取完成 (進度: 542/566)
# 第 544 頁爬取完成 (進度: 543/566)
# 第 543 頁爬取完成 (進度: 544/566)
# 第 546 頁爬取完成 (進度: 545/566)
# 第 545 頁爬取完成 (進度: 546/566)
# 第 547 頁爬取完成 (進度: 547/566)
# 第 548 頁爬取完成 (進度: 548/566)
# 第 549 頁爬取完成 (進度: 549/566)
# 第 550 頁爬取完成 (進度: 550/566)
# 第 551 頁爬取完成 (進度: 551/566)
# 第 552 頁爬取完成 (進度: 552/566)
# 第 553 頁爬取完成 (進度: 553/566)
# 第 554 頁爬取完成 (進度: 554/566)
# 第 555 頁爬取完成 (進度: 555/566)
# 第 556 頁爬取完成 (進度: 556/566)
# 第 557 頁爬取完成 (進度: 557/566)
# 第 558 頁爬取完成 (進度: 558/566)
# 第 560 頁爬取完成 (進度: 559/566)
# 第 559 頁爬取完成 (進度: 560/566)
# 第 562 頁爬取完成 (進度: 561/566)
# 第 561 頁爬取完成 (進度: 562/566)
# 第 563 頁爬取完成 (進度: 563/566)
# 第 564 頁爬取完成 (進度: 564/566)
# 第 565 頁爬取完成 (進度: 565/566)
# 第 566 頁爬取完成 (進度: 566/566)
#
# 爬取完成！
# 總共爬取了 20373 個遊戲數據，共 566 頁
#
# 數據預覽:
#                                    遊戲名稱      原價     現價    折扣 價格標籤 銷售結束  \
# 0                            Golf Story  $14.99  $2.54  -83%  N/A
# 1                           Spiritfarer  $29.99  $4.49  -85%  N/A
# 2           Burnout Paradise Remastered  $29.99  $4.79  -84%  N/A
# 3                           Blasphemous  $24.99  $4.99  -80%  N/A
# 4  Ni no Kuni: Wrath of the White Witch  $49.99  $9.99  -80%  N/A
#
#                                          遊戲鏈接  頁碼
# 0                           /items/golf-story   1
# 1                          /items/spiritfarer   1
# 2          /items/burnout-paradise-remastered   1
# 3                          /items/blasphemous   1
# 4  /items/ni-no-kuni-wrath-of-the-white-witch   1
#
# 數據已保存到 dekudeals_games.csv
